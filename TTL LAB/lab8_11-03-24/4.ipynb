# %%
#Generate a dataset of random values and create a histogram using seaborn.
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Generate some random data
data = np.random.randn(100)

# Create a histogram
sns.histplot(data)

# Show the plot
plt.show()
