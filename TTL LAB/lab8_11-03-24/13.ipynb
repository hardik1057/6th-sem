# %%
# importing the required library import seaborn as sns import matplotlib.pyplot as plt # import pandas as pd # df = sns.load_dataset('titanic')
 # print(df) # print(df[['class','sex']]) # # class v / s fare barplot # sns.barplot(x = 'class', y = 'fare',hue='alone', data = df) # plt.show()
 # sns.histplot(data = df, x = "age", kde = False) # plt.show() # sns.boxplot(x="sex",y="age",data=df)
 # plt.show() data=[[46,30],[68,40]] print(data) sns.heatmap(data = data) # Show the plot plt.show()

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset('titanic')

print(df[['class','sex']])

sns.barplot(x='class', y='fare', hue='alone', data=df)
plt.title('Class vs Fare Barplot')
plt.show()

sns.histplot(data=df, x="age", kde=False)
plt.title('Age Histogram')
plt.show()

sns.boxplot(x="sex", y="age", data=df)
plt.title('Boxplot of Age grouped by Sex')
plt.show()

data = [[46, 30], [68, 40]]
sns.heatmap(data=data, annot=True, fmt='d', cmap='coolwarm')
plt.title('Example Heatmap')
plt.show()
# Out:
#       class     sex
# 0     Third    male
# 1     First  female
# 2     Third  female
# 3     First  female
# 4     Third    male
# ..      ...     ...
# 886  Second    male
# 887   First  female
# 888   Third  female
# 889   First    male
# 890   Third    male
#
# [891 rows x 2 columns]
