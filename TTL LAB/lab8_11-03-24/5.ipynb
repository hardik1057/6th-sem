# %%
#Create a boxplot using seaborn for a dataset with multiple categories.
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt 

# Create a dataframe
df = pd.DataFrame({'category': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'value': [5, 8, 1, 7, 8, 2]})

# Create a boxplot
sns.boxplot(
    x = "category",
    y = "value",
    showmeans=True,
    data=df
)

# Rotate x labels to prevent overlapping
plt.xticks(rotation=45)
plt.show()
