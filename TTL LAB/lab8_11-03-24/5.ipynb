# %%
#Create a boxplot using seaborn for a dataset with multiple categories.
import seaborn as sns
import pandas as pd

# Create a dataframe
df = pd.DataFrame({'category': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'value': [5, 8, 1, 7, 8, 2]})

# Create a boxplot
sns.boxplot(
    x = "category",
    y = "value",
    showmeans=True,
    data=df
)

# Rotate x labels to prevent overlapping
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 18
#      10 sns.boxplot(
#      11     x = "category",
#      12     y = "value",
#      13     showmeans=True,
#      14     data=df
#      15 )
#      17 # Rotate x labels to prevent overlapping
# ---> 18 plt.xticks(rotation=45)
#      19 plt.show()
#
# NameError: name 'plt' is not defined
